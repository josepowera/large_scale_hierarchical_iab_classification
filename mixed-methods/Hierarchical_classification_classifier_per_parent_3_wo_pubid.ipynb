# %% [markdown]
# FEATURES: title, preprocessed content, length_preprocessed_content
#
# MODEL: Logistic Regression only (ignored rows having only one class to be predicted)

# %%
import psycopg2
import pandas as pd
import json
import pandas.io.sql as sqlio
# preprocess
from nltk.corpus import stopwords
import re

# %%
# %config InlineBackend.figure_format = 'retina'
from pathlib import Path
import time
import pickle
from contextlib import contextmanager
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.base import BaseEstimator
@contextmanager
def timer(name):
    t0 = time.time()
    yield
    print(f'[{name}] done in {time.time() - t0:.0f} s')

# %%
train_data=pd.read_csv("train_data3.csv")
train_data.head()
# Out:
#    index                                                 id  \
# 0    133  https://www.whowhatwear.com/5-looks-that-put-b...
# 1    189  https://www.wisebread.com/what-you-need-to-kno...
# 2    401  https://www.theturekclinic.com/blog/mindful-ea...
# 3    198  https://www.news-medical.net/news/20190611/Ear...
# 4     24  https://hobbylark.com/card-games/Top-Strongest...
#
#                                              content  \
# 0  After seeing burgundy boots on some of our fav...
# 1  According to a September 29, 2009 Fidelity Inv...
# 2  “Thou shouldst eat to live; not live to eat,” ...
# 3  Researchers continue to dig for molecular clue...
# 4  As any duelist knows, the vast majority of Yu-...
#
#                                                title  \
# 0  5 Looks That Put Burgundy Boots On Our Must-Ha...
# 1                  How to Make the Most of Your 401K
# 2                                     Mindful Eating
# 3  Early life adversity and high levels of FKBP5 ...
# 4  Top 10 Strongest (Highest ATK) Monsters in Yu-...
#
#                                 preprocessed_content                 label  \
# 0  seeing burgundy boot favorite street style blo...  Womens\ Casual\ Wear
# 1  according september fidelity investments study...   Personal\ Investing
# 2  thou shouldst eat live live eat said socrates ...          Mens\ Health
# 3  researchers continue dig molecular clue better...   Hormonal\ Disorders
# 4  duelist know vast majority yu gi oh match end ...           Card\ Games
#
#                                            hierarchy  hierarchy_#tiers  \
# 0  [{'Style & Fashion': {"Women's Fashion": {"Wom...                 4
# 1       [{'Personal Finance': 'Personal Investing'}]                 2
# 2               [{'Healthy Living': "Men's Health"}]                 2
# 3  [{'Medical Health': {'Diseases and Conditions'...                 4
# 4  [{'Hobbies & Interests': {'Games and Puzzles':...                 3
#
#                  tier1                    tier2  \
# 0      Style & Fashion           Womens Fashion
# 1     Personal Finance       Personal Investing
# 2       Healthy Living              Mens Health
# 3       Medical Health  Diseases and Conditions
# 4  Hobbies & Interests        Games and Puzzles
#
#                               tier3               tier4
# 0                   Womens Clothing  Womens Casual Wear
# 1                               NaN                 NaN
# 2                               NaN                 NaN
# 3  Endocrine and Metabolic Diseases  Hormonal Disorders
# 4                        Card Games                 NaN

# %%
train_data['tier1'].value_counts()
# Out:
# Sports                      927
# Business and Finance        900
# Technology & Computing      700
# Style & Fashion             644
# Personal Finance            600
# Travel                      578
# Hobbies & Interests         521
# Medical Health              500
# Education                   490
# Books and Literature        365
# Pop Culture                 300
# Music and Audio             300
# Automotive                  300
# Movies                      279
# Events and Attractions      271
# Family and Relationships    200
# Food & Drink                200
# Science                     200
# Healthy Living              200
# Real Estate                 200
# Religion & Spirituality     100
# Pets                        100
# Careers                     100
# News and Politics           100
# Shopping                     92
# Name: tier1, dtype: int64

# %%
train_data['tier2'].value_counts()
# Out:
# Computing                     700
# Travel Type                   478
# Womens Fashion                444
# Industries                    400
# Business                      300
#                              ...
# Family and Children Movies     61
# Model Toys                     59
# Crime and Mystery Movies       59
# Extreme Sports                 20
# Golf                           17
# Name: tier2, Length: 63, dtype: int64

# %%
train_data['tier3'].value_counts()
# Out:
# Internet                              400
# Womens Clothing                       244
# Endocrine and Metabolic Diseases      200
# Motor Insurance                       200
# Rail Travel                           150
# Mutual Funds                          100
# Housing Market                        100
# Laptops                               100
# Gasoline Prices                       100
# Credit Cards                          100
# Womens Accessories                    100
# Standardized Testing                  100
# Consumer Issues                       100
# Womens Shoes and Footwear             100
# Family Travel                         100
# Mens Clothing                         100
# Business Accounting & Finance         100
# Classic Cars                          100
# Apparel Industry                      100
# Computer Peripherals                  100
# Van                                   100
# Computer Software and Applications    100
# Publishing Industry                   100
# Defense Industry                      100
# Reproductive Health                   100
# Business Travel                       100
# Africa Travel                         100
# Audio Production                      100
# Adoption and Fostering                100
# Business Banking & Finance            100
# Pharmaceutical Industry               100
# Day Trips                              88
# Card Games                             63
# Anniversary                            40
# Air Travel                             40
# Funeral                                31
# Waterskiing and Wakeboarding           20
# Name: tier3, dtype: int64

# %%
train_data['tier4'].value_counts()
# Out:
# Womens Casual Wear            200
# Menopause                     100
# Web Conferencing              100
# Shareware and Freeware        100
# Mens Business Wear            100
# Web Hosting                   100
# Infertility                   100
# Venture Capital               100
# Womens Jewelry and Watches    100
# IT and Internet Support       100
# Hormonal Disorders            100
# Internet of Things            100
# Recalls                       100
# Womens Sportswear              44
# Name: tier4, dtype: int64

# %%
tf_idf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', ngram_range=(1, 2))

# multinomial logistic regression 
logit = LogisticRegression(C=1e2, n_jobs=4, solver='lbfgs', 
                           random_state=42, verbose=0, 
                           multi_class='multinomial')

# %%
class Hierarchical(BaseEstimator):
    
    def __init__(self, 
                 base_model, 
                 model_store_path,
                 class_separator = '/',
                 min_size_to_train=50
                ):

        self.base_model = base_model
        self.model_store_path = Path(model_store_path)
        self.class_separator = class_separator
        self.min_size_to_train = min_size_to_train
        
        self.model_store_path.mkdir(exist_ok=True)
        
    def fit(self, X, y):
        
        lev1_classes = [label.split(self.class_separator)[0]
                        for label in y]
        
        with timer('Training level 1 model'):
            self.base_model.fit(X, lev1_classes)
            
            
            with open(self.model_store_path / 'level1_model.pkl', 'wb') as f:
                pickle.dump(self.base_model, f)
        
        
        for lev1_class in np.unique(lev1_classes):
            with timer(f'Training level 2 model for parent: {lev1_class}'):
                curr_X = X.loc[y.str.startswith(lev1_class)]
                curr_y = y.loc[y.str.startswith(lev1_class)].apply(lambda s: s.split(self.class_separator)[1]).str.strip()
                curr_y=curr_y[curr_y!=""]
                curr_X=X.loc[curr_y.index]
                if len(curr_X) < self.min_size_to_train:
                    print(f"Skipped class {lev1_class.replace(' ', '_')} as less data for further classification: {len(curr_X)}")
                    continue
                model_name = f"level2_model_{lev1_class.replace(' ', '_')}.pkl"
                try:
                    self.base_model.fit(curr_X, curr_y)                                  
                    with open(self.model_store_path / model_name, 'wb') as f:
                        pickle.dump(self.base_model, f)
                except ValueError:
                    #when no. of classes=1 within the main class
                    print(np.unique(curr_y),"in", lev1_class)
                    continue

        lev2_classes = [label.split(self.class_separator)[1]
                        for label in y]
        
        for lev2_class in np.unique(lev2_classes):
            if lev2_class=="":
                continue
            with timer(f'Training level 3 model for parent: {lev2_class}'):
                curr_X = X.loc[y.str.contains(lev2_class)]
                curr_y = y.loc[y.str.contains(lev2_class)].apply(lambda s: s.split(self.class_separator)[2]).str.strip()
                curr_y=curr_y[curr_y!=""]
                curr_X=X.loc[curr_y.index]
                if len(curr_X) < self.min_size_to_train:
                    print(f"Skipped class {lev2_class.replace(' ', '_')} as less data for further classification: {len(curr_X)}")
                    continue
                model_name = f"level3_model_{lev2_class.replace(' ', '_')}.pkl"
                try:
                    self.base_model.fit(curr_X, curr_y)                                  
                    with open(self.model_store_path / model_name, 'wb') as f:
                        pickle.dump(self.base_model, f)
                except ValueError:
                    print(np.unique(curr_y),"in", lev2_class)
                    continue

        lev3_classes = [label.split(self.class_separator)[2]
                        for label in y]
        
        for lev3_class in np.unique(lev3_classes):
            if lev3_class=="":
                continue
            with timer(f'Training level 4 model for parent: {lev3_class}'):
                curr_X = X.loc[y.str.contains(lev3_class)]
                curr_y = y.loc[y.str.contains(lev3_class)].apply(lambda s: s.split(self.class_separator)[3]).str.strip()
                curr_y=curr_y[curr_y!=""]
                curr_X=X.loc[curr_y.index]
                if len(curr_X) < self.min_size_to_train:
                    print(f"Skipped class {lev2_class.replace(' ', '_')} as less data for further classification: {len(curr_X)}")
                    continue
                model_name = f"level4_model_{lev3_class.replace(' ', '_')}.pkl"
                try:
                    self.base_model.fit(curr_X, curr_y)                                  
                    with open(self.model_store_path / model_name, 'wb') as f:
                        pickle.dump(self.base_model, f)
                except ValueError:
                    print(np.unique(curr_y),"in", lev3_class)
                    continue

    def predict(self, X):
        
        model_name =  'level1_model.pkl'
        with open(self.model_store_path / model_name, 'rb') as f:
            level1_model = pickle.load(f)
        
        level1_preds = level1_model.predict(X)
            
        level2_preds = np.zeros_like(level1_preds)
        level2_preds = np.array(level2_preds, dtype='object') 
            
        for lev1_class in np.unique(level1_preds):
            idx = level1_preds == lev1_class
            curr_X = X.iloc[idx]
            
            model_name = f"level2_model_{lev1_class.replace(' ', '_')}.pkl"
            
            if Path(self.model_store_path / model_name).exists():
            
                with open(self.model_store_path / model_name, 'rb') as f:
                    level2_model = pickle.load(f)

                curr_level2_preds = level2_model.predict(curr_X)
                level2_preds[idx] = curr_level2_preds
            
            else:
                level2_preds[idx] = lev1_class
        
        level3_preds = np.zeros_like(level2_preds)
        level3_preds = np.array(level3_preds, dtype='object') 
        level2_preds=level2_preds.astype(str)
        for lev2_class in np.unique(level2_preds):
            idx = level2_preds == lev2_class
            curr_X = X.iloc[idx]       
            if lev2_class=="":
                level3_preds[idx]=""
                continue
            model_name = f"level3_model_{lev2_class.replace(' ', '_')}.pkl"
            if Path(self.model_store_path / model_name).exists():
                with open(self.model_store_path / model_name, 'rb') as f:
                    level3_model = pickle.load(f)

                curr_level3_preds = level3_model.predict(curr_X)
                level3_preds[idx] = curr_level3_preds
            
            else:
                level3_preds[idx] = lev2_class
            
        level4_preds = np.zeros_like(level3_preds)
        level4_preds = np.array(level4_preds, dtype='object') 
        level3_preds=level3_preds.astype(str)   
        for lev3_class in np.unique(level3_preds):
            idx = level3_preds == lev3_class
            curr_X = X.iloc[idx]       
            if lev3_class=="":
                level4_preds[idx]=""
                continue
            model_name = f"level4_model_{lev3_class.replace(' ', '_')}.pkl"
            if Path(self.model_store_path / model_name).exists():
                with open(self.model_store_path / model_name, 'rb') as f:
                    level4_model = pickle.load(f)

                curr_level4_preds = level4_model.predict(curr_X)
                level4_preds[idx] = curr_level4_preds
            
            else:
                level4_preds[idx] = lev3_class
        
                
        return level1_preds, level2_preds,level3_preds,level4_preds

# %% [markdown]
# feature exploration

# %%
train_data.columns
# Out:
# Index(['index', 'id', 'content', 'title', 'preprocessed_content', 'label',
#        'hierarchy', 'hierarchy_#tiers', 'tier1', 'tier2', 'tier3', 'tier4'],
#       dtype='object')

# %%
train_data=train_data.drop(['index'],axis=1)

# %%
pd.isna(train_data).sum()
# Out:
# id                         0
# content                  158
# title                    222
# preprocessed_content     175
# label                      0
# hierarchy                  0
# hierarchy_#tiers           0
# tier1                      0
# tier2                    492
# tier3                   5091
# tier4                   7723
# dtype: int64

# %%
def length(x):
    if not pd.isna(x):
        return (len(x.split(" ")))
train_data['length_preprocessed_content']=train_data['preprocessed_content'].apply(length)

# %%
train_data['length_preprocessed_content'].describe()
# Out:
# count    8992.000000
# mean      433.420262
# std       400.555787
# min         1.000000
# 25%       177.000000
# 50%       334.000000
# 75%       568.000000
# max      6528.000000
# Name: length_preprocessed_content, dtype: float64

# %% [markdown]
# new training and test data

# %%
len(train_data)
# Out:
# 9167

# %%
train_data=train_data.fillna('')

# %%
train_data['tier1']=train_data['tier1'].str.strip()
train_data['tier2']=train_data['tier2'].str.strip()
train_data['tier3']=train_data['tier3'].str.strip()
train_data['tier4']=train_data['tier4'].str.strip()

# %%
train_data['tier1_tier2_tier3_tier4'] = train_data['tier1']+ '/' + train_data['tier2']+ '/' + train_data['tier3']+'/' + train_data['tier4']
train_data.head()
# Out:
#                                                   id  \
# 0  https://www.whowhatwear.com/5-looks-that-put-b...
# 1  https://www.wisebread.com/what-you-need-to-kno...
# 2  https://www.theturekclinic.com/blog/mindful-ea...
# 3  https://www.news-medical.net/news/20190611/Ear...
# 4  https://hobbylark.com/card-games/Top-Strongest...
#
#                                              content  \
# 0  After seeing burgundy boots on some of our fav...
# 1  According to a September 29, 2009 Fidelity Inv...
# 2  “Thou shouldst eat to live; not live to eat,” ...
# 3  Researchers continue to dig for molecular clue...
# 4  As any duelist knows, the vast majority of Yu-...
#
#                                                title  \
# 0  5 Looks That Put Burgundy Boots On Our Must-Ha...
# 1                  How to Make the Most of Your 401K
# 2                                     Mindful Eating
# 3  Early life adversity and high levels of FKBP5 ...
# 4  Top 10 Strongest (Highest ATK) Monsters in Yu-...
#
#                                 preprocessed_content                 label  \
# 0  seeing burgundy boot favorite street style blo...  Womens\ Casual\ Wear
# 1  according september fidelity investments study...   Personal\ Investing
# 2  thou shouldst eat live live eat said socrates ...          Mens\ Health
# 3  researchers continue dig molecular clue better...   Hormonal\ Disorders
# 4  duelist know vast majority yu gi oh match end ...           Card\ Games
#
#                                            hierarchy  hierarchy_#tiers  \
# 0  [{'Style & Fashion': {"Women's Fashion": {"Wom...                 4
# 1       [{'Personal Finance': 'Personal Investing'}]                 2
# 2               [{'Healthy Living': "Men's Health"}]                 2
# 3  [{'Medical Health': {'Diseases and Conditions'...                 4
# 4  [{'Hobbies & Interests': {'Games and Puzzles':...                 3
#
#                  tier1                    tier2  \
# 0      Style & Fashion           Womens Fashion
# 1     Personal Finance       Personal Investing
# 2       Healthy Living              Mens Health
# 3       Medical Health  Diseases and Conditions
# 4  Hobbies & Interests        Games and Puzzles
#
#                               tier3               tier4  \
# 0                   Womens Clothing  Womens Casual Wear
# 1
# 2
# 3  Endocrine and Metabolic Diseases  Hormonal Disorders
# 4                        Card Games
#
#   length_preprocessed_content  \
# 0                          31
# 1                         778
# 2                         363
# 3                         356
# 4                          63
#
#                              tier1_tier2_tier3_tier4
# 0  Style & Fashion/Womens Fashion/Womens Clothing...
# 1              Personal Finance/Personal Investing//
# 2                       Healthy Living/Mens Health//
# 3  Medical Health/Diseases and Conditions/Endocri...
# 4  Hobbies & Interests/Games and Puzzles/Card Games/

# %%
train_data['tier1_tier2_tier3_tier4'].value_counts().head()
# Out:
# Sports/Cricket//                                                     200
# Style & Fashion/Womens Fashion/Womens Clothing/Womens Casual Wear    200
# Education/Homework and Study//                                       200
# Personal Finance/Insurance/Motor Insurance/                          200
# Travel/Travel Type/Rail Travel/                                      150
# Name: tier1_tier2_tier3_tier4, dtype: int64

# %%
r1=train_data[train_data['tier3'].str.contains("'s")]['tier3'].index
train_data.loc[r1,'tier3']=train_data.loc[r1,'tier3'].str.replace("'s","s")

r2=train_data[train_data['tier2'].str.contains("'s")]['tier2'].index
train_data.loc[r2,'tier2']=train_data.loc[r2,'tier2'].str.replace("'s","s")

train_data['tier1']=train_data['tier1'].str.strip()
train_data['tier2']=train_data['tier2'].str.strip()
train_data['tier3']=train_data['tier3'].str.strip()
train_data['tier4']=train_data['tier4'].str.strip()

train_data['tier2']=train_data['tier2'].str.strip("\"")
train_data['tier3']=train_data['tier3'].str.strip("\"")
train_data['tier4']=train_data['tier4'].str.strip("\"")

# %%
train_data.columns
# Out:
# Index(['id', 'content', 'title', 'preprocessed_content', 'label', 'hierarchy',
#        'hierarchy_#tiers', 'tier1', 'tier2', 'tier3', 'tier4',
#        'length_preprocessed_content', 'tier1_tier2_tier3_tier4'],
#       dtype='object')

# %%
ind=train_data[train_data['title']==""].index
ind1=train_data[train_data['preprocessed_content']==""].index

# %%
train_data=train_data[~(train_data.index.isin(ind))]
train_data=train_data[~(train_data.index.isin(ind1))]
len(train_data)
# Out:
# 8774

# %%
features1=train_data[['title','preprocessed_content','length_preprocessed_content']]#,'tier1','tier2','tier3','tier4']]
labels1=train_data[['tier1', 'tier2', 'tier3', 'tier4', 'tier1_tier2_tier3_tier4']]
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(features1, labels1,test_size=0.2,random_state=42,stratify=labels1['tier4'])

# %%
X_train_new = X_train_new.reset_index(drop=True)
y_train_new = y_train_new.reset_index(drop=True)
X_test_new = X_test_new.reset_index(drop=True)
y_test_new = y_test_new.reset_index(drop=True)

# %% [markdown]
# without embedding and other features(length of description and publisher_id)

# %%
from category_encoders import TargetEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
combine = make_column_transformer((tf_idf,'title'),(tf_idf,'preprocessed_content'),(StandardScaler(),['length_preprocessed_content']),remainder='passthrough')

# %%
import numpy as np
base_model = Pipeline([('combine', combine), 
                       ('logit', logit)])

model =Hierarchical(
    base_model=base_model,
    model_store_path='modelsnew1'
)

model.fit(X_train_new,y_train_new['tier1_tier2_tier3_tier4'])
# Out:
# [Training level 1 model] done in 115 s
# [Training level 2 model for parent: Automotive] done in 2 s
# [Training level 2 model for parent: Books and Literature] done in 3 s
# [Training level 2 model for parent: Business and Finance] done in 5 s
# ['Career Advice'] in Careers
# [Training level 2 model for parent: Careers] done in 0 s
# [Training level 2 model for parent: Education] done in 3 s
# [Training level 2 model for parent: Events and Attractions] done in 0 s
# ['Parenting'] in Family and Relationships
# [Training level 2 model for parent: Family and Relationships] done in 0 s
# ['Desserts and Baking'] in Food & Drink
# [Training level 2 model for parent: Food & Drink] done in 0 s
# [Training level 2 model for parent: Healthy Living] done in 1 s
# [Training level 2 model for parent: Hobbies & Interests] done in 3 s
# [Training level 2 model for parent: Medical Health] done in 2 s
# [Training level 2 model for parent: Movies] done in 3 s
# [Training level 2 model for parent: Music and Audio] done in 2 s
# ['Disasters'] in News and Politics
# [Training level 2 model for parent: News and Politics] done in 0 s
# [Training level 2 model for parent: Personal Finance] done in 2 s
# Skipped class Pets as less data for further classification: 0
# [Training level 2 model for parent: Pets] done in 0 s
# [Training level 2 model for parent: Pop Culture] done in 1 s
# [Training level 2 model for parent: Real Estate] done in 1 s
# ['Sikhism'] in Religion & Spirituality
# [Training level 2 model for parent: Religion & Spirituality] done in 0 s
# [Training level 2 model for parent: Science] done in 1 s
# [Training level 2 model for parent: Sports] done in 4 s
# ['Womens Fashion'] in Style & Fashion
# [Training level 2 model for parent: Style & Fashion] done in 1 s
# ['Computing'] in Technology & Computing
# [Training level 2 model for parent: Technology & Computing] done in 3 s
# [Training level 2 model for parent: Travel] done in 2 s
# Skipped class Amusement_and_Theme_Parks as less data for further classification: 0
# [Training level 3 model for parent: Amusement and Theme Parks] done in 0 s
# Skipped class Art_and_Photography_Books as less data for further classification: 0
# [Training level 3 model for parent: Art and Photography Books] done in 0 s
# ['Van'] in Auto Body Styles
# [Training level 3 model for parent: Auto Body Styles] done in 0 s
# Skipped class Auto_Safety as less data for further classification: 0
# [Training level 3 model for parent: Auto Safety] done in 0 s
# ['Classic Cars'] in Auto Type
# [Training level 3 model for parent: Auto Type] done in 0 s
# Skipped class Beekeeping as less data for further classification: 0
# [Training level 3 model for parent: Beekeeping] done in 0 s
# Skipped class Birdwatching as less data for further classification: 0
# [Training level 3 model for parent: Birdwatching] done in 0 s
# Skipped class Bowling as less data for further classification: 0
# [Training level 3 model for parent: Bowling] done in 0 s
# [Training level 3 model for parent: Business] done in 6 s
# Skipped class Career_Advice as less data for further classification: 0
# [Training level 3 model for parent: Career Advice] done in 0 s
# Skipped class Celebrity_Deaths as less data for further classification: 0
# [Training level 3 model for parent: Celebrity Deaths] done in 0 s
# Skipped class Celebrity_Families as less data for further classification: 0
# [Training level 3 model for parent: Celebrity Families] done in 0 s
# Skipped class Celebrity_Pregnancy as less data for further classification: 0
# [Training level 3 model for parent: Celebrity Pregnancy] done in 0 s
# Skipped class Comedy_Movies as less data for further classification: 0
# [Training level 3 model for parent: Comedy Movies] done in 0 s
# [Training level 3 model for parent: Computing] done in 4 s
# ['Audio Production'] in Content Production
# [Training level 3 model for parent: Content Production] done in 0 s
# Skipped class Cookbooks as less data for further classification: 0
# [Training level 3 model for parent: Cookbooks] done in 0 s
# Skipped class Country_Music as less data for further classification: 0
# [Training level 3 model for parent: Country Music] done in 0 s
# Skipped class Cricket as less data for further classification: 0
# [Training level 3 model for parent: Cricket] done in 0 s
# Skipped class Crime_and_Mystery_Movies as less data for further classification: 0
# [Training level 3 model for parent: Crime and Mystery Movies] done in 0 s
# Skipped class Dance_and_Electronic_Music as less data for further classification: 0
# [Training level 3 model for parent: Dance and Electronic Music] done in 0 s
# Skipped class Desserts_and_Baking as less data for further classification: 0
# [Training level 3 model for parent: Desserts and Baking] done in 0 s
# Skipped class Disasters as less data for further classification: 0
# [Training level 3 model for parent: Disasters] done in 0 s
# [Training level 3 model for parent: Diseases and Conditions] done in 1 s
# [Training level 3 model for parent: Economy] done in 1 s
# ['Standardized Testing'] in Educational Assessment
# [Training level 3 model for parent: Educational Assessment] done in 1 s
# Skipped class Extreme_Sports as less data for further classification: 17
# [Training level 3 model for parent: Extreme Sports] done in 0 s
# Skipped class Family_and_Children_Movies as less data for further classification: 0
# [Training level 3 model for parent: Family and Children Movies] done in 0 s
# Skipped class Field_Hockey as less data for further classification: 0
# [Training level 3 model for parent: Field Hockey] done in 0 s
# Skipped class Figure_Skating as less data for further classification: 0
# [Training level 3 model for parent: Figure Skating] done in 0 s
# Skipped class Games_and_Puzzles as less data for further classification: 49
# [Training level 3 model for parent: Games and Puzzles] done in 0 s
# Skipped class Geography as less data for further classification: 0
# [Training level 3 model for parent: Geography] done in 0 s
# Skipped class Golf as less data for further classification: 0
# [Training level 3 model for parent: Golf] done in 0 s
# Skipped class Homework_and_Study as less data for further classification: 0
# [Training level 3 model for parent: Homework and Study] done in 0 s
# Skipped class Hotel_Properties as less data for further classification: 0
# [Training level 3 model for parent: Hotel Properties] done in 0 s
# [Training level 3 model for parent: Industries] done in 2 s
# ['Motor Insurance'] in Insurance
# [Training level 3 model for parent: Insurance] done in 1 s
# Skipped class Martial_Arts as less data for further classification: 0
# [Training level 3 model for parent: Martial Arts] done in 0 s
# Skipped class Medical_Tests as less data for further classification: 0
# [Training level 3 model for parent: Medical Tests] done in 0 s
# Skipped class Mens_Health as less data for further classification: 0
# [Training level 3 model for parent: Mens Health] done in 0 s
# Skipped class Model_Toys as less data for further classification: 0
# [Training level 3 model for parent: Model Toys] done in 0 s
# Skipped class Oldies_Music as less data for further classification: 0
# [Training level 3 model for parent: Oldies Music] done in 0 s
# ['Adoption and Fostering'] in Parenting
# [Training level 3 model for parent: Parenting] done in 0 s
# [Training level 3 model for parent: Personal Celebrations & Life Events] done in 0 s
# ['Credit Cards'] in Personal Debt
# [Training level 3 model for parent: Personal Debt] done in 1 s
# ['Mutual Funds'] in Personal Investing
# [Training level 3 model for parent: Personal Investing] done in 0 s
# Skipped class Pharmaceutical_Drugs as less data for further classification: 0
# [Training level 3 model for parent: Pharmaceutical Drugs] done in 0 s
# Skipped class Physics as less data for further classification: 0
# [Training level 3 model for parent: Physics] done in 0 s
# Skipped class Poetry as less data for further classification: 0
# [Training level 3 model for parent: Poetry] done in 0 s
# Skipped class Primary_Education as less data for further classification: 0
# [Training level 3 model for parent: Primary Education] done in 0 s
# Skipped class Retail_Property as less data for further classification: 0
# [Training level 3 model for parent: Retail Property] done in 0 s
# Skipped class Romance_Movies as less data for further classification: 0
# [Training level 3 model for parent: Romance Movies] done in 0 s
# Skipped class Sailing as less data for further classification: 0
# [Training level 3 model for parent: Sailing] done in 0 s
# Skipped class Sikhism as less data for further classification: 0
# [Training level 3 model for parent: Sikhism] done in 0 s
# Skipped class Special_Education as less data for further classification: 0
# [Training level 3 model for parent: Special Education] done in 0 s
# Skipped class Travel_Books as less data for further classification: 0
# [Training level 3 model for parent: Travel Books] done in 0 s
# ['Africa Travel'] in Travel Locations
# [Training level 3 model for parent: Travel Locations] done in 0 s
# [Training level 3 model for parent: Travel Type] done in 2 s
# Skipped class Volleyball as less data for further classification: 0
# [Training level 3 model for parent: Volleyball] done in 0 s
# Skipped class Water_Polo as less data for further classification: 0
# [Training level 3 model for parent: Water Polo] done in 0 s
# [Training level 3 model for parent: Womens Fashion] done in 1 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 3 model for parent: Womens Health] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Adoption and Fostering] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Africa Travel] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Air Travel] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Anniversary] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Apparel Industry] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Audio Production] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Business Accounting & Finance] done in 0 s
# ['Venture Capital'] in Business Banking & Finance
# [Training level 4 model for parent: Business Banking & Finance] done in 1 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Business Travel] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Card Games] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Classic Cars] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Computer Peripherals] done in 0 s
# ['Shareware and Freeware'] in Computer Software and Applications
# [Training level 4 model for parent: Computer Software and Applications] done in 1 s
# ['Recalls'] in Consumer Issues
# [Training level 4 model for parent: Consumer Issues] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Credit Cards] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Day Trips] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Defense Industry] done in 0 s
# [Training level 4 model for parent: Endocrine and Metabolic Diseases] done in 1 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Family Travel] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Funeral] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Gasoline Prices] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Housing Market] done in 0 s
# [Training level 4 model for parent: Internet] done in 2 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Laptops] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Motor Insurance] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Mutual Funds] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Pharmaceutical Industry] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Publishing Industry] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Rail Travel] done in 0 s
# ['Infertility'] in Reproductive Health
# [Training level 4 model for parent: Reproductive Health] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Standardized Testing] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Van] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Waterskiing and Wakeboarding] done in 0 s
# ['Womens Jewelry and Watches'] in Womens Accessories
# [Training level 4 model for parent: Womens Accessories] done in 0 s
# [Training level 4 model for parent: Womens Clothing] done in 0 s
# Skipped class Womens_Health as less data for further classification: 0
# [Training level 4 model for parent: Womens Shoes and Footwear] done in 0 s

# %%
level1_pred, level2_pred, level3_pred, level4_pred= model.predict(X_test_new)

# %%
oneclass=['Career Advice','Parenting','Desserts and Baking','Disasters','Sikhism','Womens Fashion','Computing','Van','Classic Cars','Audio Production','Standardized Testing','Motor Insurance','Adoption and Fostering','Credit Cards','Mutual Funds','Africa Travel','Venture Capital','Shareware and Freeware','Recalls','Infertility','Womens Jewelry and Watches']

# %%
finalresult=pd.concat([X_test_new,y_test_new['tier1_tier2_tier3_tier4'],y_test_new['tier1'],y_test_new['tier2'],y_test_new['tier3'],y_test_new['tier4'],pd.DataFrame(level1_pred,columns=['pred1']),pd.DataFrame(level2_pred,columns=['pred2']),pd.DataFrame(level3_pred,columns=['pred3']),pd.DataFrame(level4_pred,columns=['pred4'])],axis=1)

# %%
finalresult
# Out:
#                                                   title  \
# 0     Menopause is not the end of women&#39;s love life
# 1     BREAKING: Tomorrowland Winter 2020 Is Official...
# 2                  Credit Cards Stoke JPMorgan Comeback
# 3     1993 Nissan President Is The RWD Flagship You ...
# 4     Immaculate Car Collection In Mexico Is Eclecti...
# ...                                                 ...
# 1750  How Georgia Satellites' 'Keep Your Hands to Yo...
# 1751  The Farm Bill works for birds — and needs your...
# 1752                                 Adoption Champions
# 1753            Poster poems: seeking refuge and asylum
# 1754  It's Time to Plan for How Quantum Computing Co...
#
#                                    preprocessed_content  \
# 0     menopause signal end woman love life fact woma...
# 1     french government shutting tomorrowland winter...
# 2     credit card well jpm jpmorgan chase one leadin...
# 3     japanese domestic market jdm car bee knee dist...
# 4     cool car universal language passion collecting...
# ...                                                 ...
# 1750  thirty year ago georgia satellites released on...
# 1751  farmland devoid bird certain part farmer land ...
# 1752  adoption become widely discussed supported eve...
# 1753  channel tunnel besieged dispossessed mediterra...
# 1754  quantum computer crack strongest encryption me...
#
#      length_preprocessed_content  \
# 0                            225
# 1                            125
# 2                            490
# 3                            156
# 4                            204
# ...                          ...
# 1750                         884
# 1751                         420
# 1752                         307
# 1753                         378
# 1754                         611
#
#                                 tier1_tier2_tier3_tier4  \
# 0     Medical Health/Diseases and Conditions/Endocri...
# 1          Music and Audio/Dance and Electronic Music//
# 2          Personal Finance/Personal Debt/Credit Cards/
# 3                    Automotive/Auto Type/Classic Cars/
# 4                    Automotive/Auto Type/Classic Cars/
# ...                                                 ...
# 1750                    Music and Audio/Country Music//
# 1751                 Hobbies & Interests/Birdwatching//
# 1752  Family and Relationships/Parenting/Adoption an...
# 1753                      Books and Literature/Poetry//
# 1754                                  Science/Physics//
#
#                          tier1                       tier2  \
# 0               Medical Health     Diseases and Conditions
# 1              Music and Audio  Dance and Electronic Music
# 2             Personal Finance               Personal Debt
# 3                   Automotive                   Auto Type
# 4                   Automotive                   Auto Type
# ...                        ...                         ...
# 1750           Music and Audio               Country Music
# 1751       Hobbies & Interests                Birdwatching
# 1752  Family and Relationships                   Parenting
# 1753      Books and Literature                      Poetry
# 1754                   Science                     Physics
#
#                                  tier3      tier4                     pred1  \
# 0     Endocrine and Metabolic Diseases  Menopause            Medical Health
# 1                                                           Music and Audio
# 2                         Credit Cards                     Personal Finance
# 3                         Classic Cars                           Automotive
# 4                         Classic Cars                           Automotive
# ...                                ...        ...                       ...
# 1750                                                        Music and Audio
# 1751                                                    Hobbies & Interests
# 1752            Adoption and Fostering             Family and Relationships
# 1753                                                   Books and Literature
# 1754                                                                Science
#
#                            pred2                             pred3  \
# 0        Diseases and Conditions  Endocrine and Metabolic Diseases
# 1     Dance and Electronic Music        Dance and Electronic Music
# 2                  Personal Debt                     Personal Debt
# 3                      Auto Type                         Auto Type
# 4                      Auto Type                         Auto Type
# ...                          ...                               ...
# 1750               Country Music                     Country Music
# 1751                Birdwatching                      Birdwatching
# 1752    Family and Relationships          Family and Relationships
# 1753                      Poetry                            Poetry
# 1754                     Physics                           Physics
#
#                            pred4
# 0                      Menopause
# 1     Dance and Electronic Music
# 2                  Personal Debt
# 3                      Auto Type
# 4                      Auto Type
# ...                          ...
# 1750               Country Music
# 1751                Birdwatching
# 1752    Family and Relationships
# 1753                      Poetry
# 1754                     Physics
#
# [1755 rows x 12 columns]

# %%
finalresult[finalresult['tier1']!=finalresult['pred1']]
# Out:
#                                                   title  \
# 12    Over 1.5K Morgans Gathered To Celebrate 108 Ye...
# 19    Commonwealth Biotechnologies to acquire GL Bio...
# 21    Getting Into The Unicorn Boom: 10 Mutual Funds...
# 46    MediSapiens launches unified cloud computing a...
# 71    IBM Quantum Computer Does Record-Breaking Chem...
# ...                                                 ...
# 1715  Port Aransas Chefs Finish Top Ten in Their Cat...
# 1716  U.S. Department of Labor Issues Final Joint Em...
# 1736  PharmSource ranks Patheon as top global contra...
# 1744  Cloud Flash, Standard Tests And Storage Versus...
# 1749  XAG Robot Joins Drone Fleet to Initiate Ground...
#
#                                    preprocessed_content  \
# 12    morgan bespoke british automaker still us wood...
# 19    commonwealth biotechnologies inc cbi nasdaq ca...
# 21    pure storage conducted ipo early october billi...
# 46    medisapiens launch first kind fully integrated...
# 71    cool sound quantum computer probably best suit...
# ...                                                 ...
# 1715  port aransas texas nov prnewswire port aransas...
# 1716  washington u department labor dol revealed fin...
# 1736  ranking based independent pharmsource r resear...
# 1744  enterprise data volume doubling every two year...
# 1749  guangzhou china feb prnewswire since emergence...
#
#      length_preprocessed_content  \
# 12                           194
# 19                           364
# 21                          1605
# 46                           245
# 71                           377
# ...                          ...
# 1715                         287
# 1716                         237
# 1736                         234
# 1744                         962
# 1749                         686
#
#                                 tier1_tier2_tier3_tier4  \
# 12                   Automotive/Auto Type/Classic Cars/
# 19                Medical Health/Pharmaceutical Drugs//
# 21    Personal Finance/Personal Investing/Mutual Funds/
# 46                Medical Health/Pharmaceutical Drugs//
# 71                                    Science/Physics//
# ...                                                 ...
# 1715  Events and Attractions/Amusement and Theme Par...
# 1716                     Real Estate/Hotel Properties//
# 1736              Medical Health/Pharmaceutical Drugs//
# 1744  Education/Educational Assessment/Standardized ...
# 1749  Business and Finance/Industries/Defense Industry/
#
#                        tier1                      tier2                 tier3  \
# 12                Automotive                  Auto Type          Classic Cars
# 19            Medical Health       Pharmaceutical Drugs
# 21          Personal Finance         Personal Investing          Mutual Funds
# 46            Medical Health       Pharmaceutical Drugs
# 71                   Science                    Physics
# ...                      ...                        ...                   ...
# 1715  Events and Attractions  Amusement and Theme Parks
# 1716             Real Estate           Hotel Properties
# 1736          Medical Health       Pharmaceutical Drugs
# 1744               Education     Educational Assessment  Standardized Testing
# 1749    Business and Finance                 Industries      Defense Industry
#
#      tier4                   pred1                      pred2  \
# 12          Events and Attractions  Amusement and Theme Parks
# 19            Business and Finance                 Industries
# 21            Business and Finance                 Industries
# 46          Technology & Computing     Technology & Computing
# 71          Technology & Computing     Technology & Computing
# ...    ...                     ...                        ...
# 1715                        Sports                    Bowling
# 1716          Business and Finance                   Business
# 1736          Business and Finance                 Industries
# 1744        Technology & Computing     Technology & Computing
# 1749        Technology & Computing     Technology & Computing
#
#                               pred3                          pred4
# 12        Amusement and Theme Parks      Amusement and Theme Parks
# 19          Pharmaceutical Industry        Pharmaceutical Industry
# 21                 Apparel Industry               Apparel Industry
# 46           Technology & Computing         Technology & Computing
# 71           Technology & Computing         Technology & Computing
# ...                             ...                            ...
# 1715                        Bowling                        Bowling
# 1716  Business Accounting & Finance  Business Accounting & Finance
# 1736        Pharmaceutical Industry        Pharmaceutical Industry
# 1744         Technology & Computing         Technology & Computing
# 1749         Technology & Computing         Technology & Computing
#
# [152 rows x 12 columns]

# %%
print("Accuracy of level 1",1-len(finalresult[finalresult['tier1']!=finalresult['pred1']])/len(finalresult))
# Out:
# Accuracy of level 1 0.9133903133903134

# %% [markdown]
# # Accuracy of level 1
# <h2><span style="color:red">0.9133903133903134</span></h2>

# %%
finalresult[(finalresult['tier2']!=finalresult['pred2'])&(finalresult['tier2']!="")]
# Out:
#                                                   title  \
# 5     How partnerships enriched the learning for Nai...
# 6               New ASUS ExpertBook A Solid Work Laptop
# 7     The Normalization of Mean Leaders: A Recipe fo...
# 8        Are Desktop PCs And Laptops Becoming Obsolete?
# 9                          Video: Don't freak, I'm Sikh
# ...                                                 ...
# 1741  Facebook Open Sources New Compression And Stor...
# 1744  Cloud Flash, Standard Tests And Storage Versus...
# 1748              The top companies hiring in June 2016
# 1749  XAG Robot Joins Drone Fleet to Initiate Ground...
# 1752                                 Adoption Champions
#
#                                    preprocessed_content  \
# 5     eight year research low income neighbourhood n...
# 6     asus expertbook b9450 first thing notice new a...
# 7     many u wondering glory day kalanicks shkrelis ...
# 8     desktop pcs laptop rendered obsolete originall...
# 9     turban reminds good person say pardeep singh v...
# ...                                                 ...
# 1741  announced open sourcing handful infrastructure...
# 1744  enterprise data volume doubling every two year...
# 1748  michael chearyso british summer time finally c...
# 1749  guangzhou china feb prnewswire since emergence...
# 1752  adoption become widely discussed supported eve...
#
#      length_preprocessed_content  \
# 5                            552
# 6                            608
# 7                            824
# 8                            524
# 9                             78
# ...                          ...
# 1741                         620
# 1744                         962
# 1748                         540
# 1749                         686
# 1752                         307
#
#                                 tier1_tier2_tier3_tier4  \
# 5                        Education/Homework and Study//
# 6             Technology & Computing/Computing/Laptops/
# 7     Business and Finance/Business/Business Banking...
# 8             Technology & Computing/Computing/Laptops/
# 9                     Religion & Spirituality/Sikhism//
# ...                                                 ...
# 1741  Technology & Computing/Computing/Computer Soft...
# 1744  Education/Educational Assessment/Standardized ...
# 1748                            Careers/Career Advice//
# 1749  Business and Finance/Industries/Defense Industry/
# 1752  Family and Relationships/Parenting/Adoption an...
#
#                          tier1                   tier2  \
# 5                    Education      Homework and Study
# 6       Technology & Computing               Computing
# 7         Business and Finance                Business
# 8       Technology & Computing               Computing
# 9      Religion & Spirituality                 Sikhism
# ...                        ...                     ...
# 1741    Technology & Computing               Computing
# 1744                 Education  Educational Assessment
# 1748                   Careers           Career Advice
# 1749      Business and Finance              Industries
# 1752  Family and Relationships               Parenting
#
#                                    tier3                   tier4  \
# 5
# 6                                Laptops
# 7             Business Banking & Finance         Venture Capital
# 8                                Laptops
# 9
# ...                                  ...                     ...
# 1741  Computer Software and Applications  Shareware and Freeware
# 1744                Standardized Testing
# 1748
# 1749                    Defense Industry
# 1752              Adoption and Fostering
#
#                          pred1                     pred2  \
# 5                    Education         Primary Education
# 6       Technology & Computing    Technology & Computing
# 7         Business and Finance                Industries
# 8       Technology & Computing    Technology & Computing
# 9      Religion & Spirituality   Religion & Spirituality
# ...                        ...                       ...
# 1741    Technology & Computing    Technology & Computing
# 1744    Technology & Computing    Technology & Computing
# 1748                   Careers                   Careers
# 1749    Technology & Computing    Technology & Computing
# 1752  Family and Relationships  Family and Relationships
#
#                          pred3                     pred4
# 5            Primary Education         Primary Education
# 6       Technology & Computing    Technology & Computing
# 7             Apparel Industry          Apparel Industry
# 8       Technology & Computing    Technology & Computing
# 9      Religion & Spirituality   Religion & Spirituality
# ...                        ...                       ...
# 1741    Technology & Computing    Technology & Computing
# 1744    Technology & Computing    Technology & Computing
# 1748                   Careers                   Careers
# 1749    Technology & Computing    Technology & Computing
# 1752  Family and Relationships  Family and Relationships
#
# [534 rows x 12 columns]

# %%
print("Accuracy of level 2",1-len(finalresult[(finalresult['tier2']!=finalresult['pred2'])&(finalresult['tier2']!="")])/len(finalresult))
# Out:
# Accuracy of level 2 0.6957264957264957

# %% [markdown]
#  # Accuracy of level 2
# <h2><span style="color:red">0.6957264957264957</span></h2>

# %%
finalresult[(finalresult['tier3']!=finalresult['pred3'])&(finalresult['tier3']!="")]
# Out:
#                                                   title  \
# 2                  Credit Cards Stoke JPMorgan Comeback
# 3     1993 Nissan President Is The RWD Flagship You ...
# 4     Immaculate Car Collection In Mexico Is Eclecti...
# 6               New ASUS ExpertBook A Solid Work Laptop
# 7     The Normalization of Mean Leaders: A Recipe fo...
# ...                                                 ...
# 1739        Durbanville restaurant outdoes Test Kitchen
# 1741  Facebook Open Sources New Compression And Stor...
# 1744  Cloud Flash, Standard Tests And Storage Versus...
# 1749  XAG Robot Joins Drone Fleet to Initiate Ground...
# 1752                                 Adoption Champions
#
#                                    preprocessed_content  \
# 2     credit card well jpm jpmorgan chase one leadin...
# 3     japanese domestic market jdm car bee knee dist...
# 4     cool car universal language passion collecting...
# 6     asus expertbook b9450 first thing notice new a...
# 7     many u wondering glory day kalanicks shkrelis ...
# ...                                                 ...
# 1739  test kitchen la colombe myoga jardine hartford...
# 1741  announced open sourcing handful infrastructure...
# 1744  enterprise data volume doubling every two year...
# 1749  guangzhou china feb prnewswire since emergence...
# 1752  adoption become widely discussed supported eve...
#
#      length_preprocessed_content  \
# 2                            490
# 3                            156
# 4                            204
# 6                            608
# 7                            824
# ...                          ...
# 1739                         195
# 1741                         620
# 1744                         962
# 1749                         686
# 1752                         307
#
#                                 tier1_tier2_tier3_tier4  \
# 2          Personal Finance/Personal Debt/Credit Cards/
# 3                    Automotive/Auto Type/Classic Cars/
# 4                    Automotive/Auto Type/Classic Cars/
# 6             Technology & Computing/Computing/Laptops/
# 7     Business and Finance/Business/Business Banking...
# ...                                                 ...
# 1739             Travel/Travel Locations/Africa Travel/
# 1741  Technology & Computing/Computing/Computer Soft...
# 1744  Education/Educational Assessment/Standardized ...
# 1749  Business and Finance/Industries/Defense Industry/
# 1752  Family and Relationships/Parenting/Adoption an...
#
#                          tier1                   tier2  \
# 2             Personal Finance           Personal Debt
# 3                   Automotive               Auto Type
# 4                   Automotive               Auto Type
# 6       Technology & Computing               Computing
# 7         Business and Finance                Business
# ...                        ...                     ...
# 1739                    Travel        Travel Locations
# 1741    Technology & Computing               Computing
# 1744                 Education  Educational Assessment
# 1749      Business and Finance              Industries
# 1752  Family and Relationships               Parenting
#
#                                    tier3                   tier4  \
# 2                           Credit Cards
# 3                           Classic Cars
# 4                           Classic Cars
# 6                                Laptops
# 7             Business Banking & Finance         Venture Capital
# ...                                  ...                     ...
# 1739                       Africa Travel
# 1741  Computer Software and Applications  Shareware and Freeware
# 1744                Standardized Testing
# 1749                    Defense Industry
# 1752              Adoption and Fostering
#
#                          pred1                     pred2  \
# 2             Personal Finance             Personal Debt
# 3                   Automotive                 Auto Type
# 4                   Automotive                 Auto Type
# 6       Technology & Computing    Technology & Computing
# 7         Business and Finance                Industries
# ...                        ...                       ...
# 1739                    Travel          Travel Locations
# 1741    Technology & Computing    Technology & Computing
# 1744    Technology & Computing    Technology & Computing
# 1749    Technology & Computing    Technology & Computing
# 1752  Family and Relationships  Family and Relationships
#
#                          pred3                     pred4
# 2                Personal Debt             Personal Debt
# 3                    Auto Type                 Auto Type
# 4                    Auto Type                 Auto Type
# 6       Technology & Computing    Technology & Computing
# 7             Apparel Industry          Apparel Industry
# ...                        ...                       ...
# 1739          Travel Locations          Travel Locations
# 1741    Technology & Computing    Technology & Computing
# 1744    Technology & Computing    Technology & Computing
# 1749    Technology & Computing    Technology & Computing
# 1752  Family and Relationships  Family and Relationships
#
# [486 rows x 12 columns]

# %%
print("Accuracy of level 3",1-len(finalresult[(finalresult['tier3']!=finalresult['pred3'])&(finalresult['tier3']!="")])/len(finalresult))
# Out:
# Accuracy of level 3 0.7230769230769231

# %% [markdown]
# # Accuracy of level 3
# <h2><span style="color:red">0.7230769230769231</span></h2>

# %%
finalresult[(finalresult['tier4']!=finalresult['pred4'])&(finalresult['tier4']!="")]
# Out:
#                                                   title  \
# 7     The Normalization of Mean Leaders: A Recipe fo...
# 32    Mindtree von ISG zu einem Marktführer für Digi...
# 34    Breast cancer medication letrozole could incre...
# 41    7 Comfy Vacation Outfit Ideas That Won't Make ...
# 55    17 Reasons to Finally Invest in a Leather Jack...
# ...                                                 ...
# 1707  The J. M. Smucker Company Issues Voluntary Rec...
# 1718   Thrillist's Ben Lerer on Success as a Young Trep
# 1737  Why CIOs Need To Think About The Internet Of T...
# 1740                   Why Venture Capitalists Heart NY
# 1741  Facebook Open Sources New Compression And Stor...
#
#                                    preprocessed_content  \
# 7     many u wondering glory day kalanicks shkrelis ...
# 32    unternehmen f r einschneidendes design thinkin...
# 34    medicine used breast cancer treatment consider...
# 41    packing vacation sometimes feel like pick dres...
# 55    every season try beautiful leather jacket look...
# ...                                                 ...
# 1707  orrville ohio dec prnewswire j smucker company...
# 1718  year old ben lerer proven sweet spot medium co...
# 1737  stunning example provincialism washington post...
# 1740  big apple recently outpaced massachusetts fame...
# 1741  announced open sourcing handful infrastructure...
#
#      length_preprocessed_content  \
# 7                            824
# 32                           701
# 34                           344
# 41                           139
# 55                            80
# ...                          ...
# 1707                         162
# 1718                         381
# 1737                         808
# 1740                         208
# 1741                         620
#
#                                 tier1_tier2_tier3_tier4  \
# 7     Business and Finance/Business/Business Banking...
# 32    Technology & Computing/Computing/Internet/IT a...
# 34    Medical Health/Diseases and Conditions/Reprodu...
# 41    Style & Fashion/Womens Fashion/Womens Clothing...
# 55    Style & Fashion/Womens Fashion/Womens Clothing...
# ...                                                 ...
# 1707  Business and Finance/Business/Consumer Issues/...
# 1718  Business and Finance/Business/Business Banking...
# 1737  Technology & Computing/Computing/Internet/Inte...
# 1740  Business and Finance/Business/Business Banking...
# 1741  Technology & Computing/Computing/Computer Soft...
#
#                        tier1                    tier2  \
# 7       Business and Finance                 Business
# 32    Technology & Computing                Computing
# 34            Medical Health  Diseases and Conditions
# 41           Style & Fashion           Womens Fashion
# 55           Style & Fashion           Womens Fashion
# ...                      ...                      ...
# 1707    Business and Finance                 Business
# 1718    Business and Finance                 Business
# 1737  Technology & Computing                Computing
# 1740    Business and Finance                 Business
# 1741  Technology & Computing                Computing
#
#                                    tier3                    tier4  \
# 7             Business Banking & Finance          Venture Capital
# 32                              Internet  IT and Internet Support
# 34                   Reproductive Health              Infertility
# 41                       Womens Clothing       Womens Casual Wear
# 55                       Womens Clothing       Womens Casual Wear
# ...                                  ...                      ...
# 1707                     Consumer Issues                  Recalls
# 1718          Business Banking & Finance          Venture Capital
# 1737                            Internet       Internet of Things
# 1740          Business Banking & Finance          Venture Capital
# 1741  Computer Software and Applications   Shareware and Freeware
#
#                        pred1                    pred2  \
# 7       Business and Finance               Industries
# 32    Technology & Computing   Technology & Computing
# 34            Medical Health  Diseases and Conditions
# 41           Style & Fashion          Style & Fashion
# 55           Style & Fashion          Style & Fashion
# ...                      ...                      ...
# 1707    Business and Finance                 Business
# 1718    Business and Finance                 Business
# 1737  Technology & Computing   Technology & Computing
# 1740    Business and Finance                 Business
# 1741  Technology & Computing   Technology & Computing
#
#                            pred3                       pred4
# 7               Apparel Industry            Apparel Industry
# 32        Technology & Computing      Technology & Computing
# 34           Reproductive Health         Reproductive Health
# 41               Style & Fashion             Style & Fashion
# 55               Style & Fashion             Style & Fashion
# ...                          ...                         ...
# 1707             Consumer Issues             Consumer Issues
# 1718  Business Banking & Finance  Business Banking & Finance
# 1737      Technology & Computing      Technology & Computing
# 1740  Business Banking & Finance  Business Banking & Finance
# 1741      Technology & Computing      Technology & Computing
#
# [231 rows x 12 columns]

# %%
print("Accuracy of level 4",1-len(finalresult[(finalresult['tier4']!=finalresult['pred4'])&(finalresult['tier4']!="")])/len(finalresult))
# Out:
# Accuracy of level 4 0.8683760683760684

# %% [markdown]
# # Accuracy of level 4
# <h2><span style="color:red">0.8683760683760684</span></h2>

# %% [markdown]
# Total Accuracy: 0.8

# %% [markdown]
# # System End-to-End Accuracy
# <h2><span style="color:red">0.80</span></h2>
